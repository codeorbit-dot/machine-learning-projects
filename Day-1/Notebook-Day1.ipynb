# %% [markdown]
# # All Notebook
# This is a sample notebook created for the all environment.

# %%
print("Hello from the all kernel")
# Out:
# Hello from the all kernel

# %%
import sys
print(sys.executable)
# Out:
# f:\VS code setup\.venv\Scripts\python.exe

# %%
#importing libraries

import matplotlib.pyplot as plt

x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]

num_bins = 5
#plotting histogram
plt.hist(x, num_bins)

plt.show()

# %%
print("Hello, World!")
print("Welcome to Python Programming")
# Out:
# Hello, World!
# Welcome to Python Programming

# %%
num1 = 10
num2 = 20

sum = num1 + num2

print("Number 1:", num1)
print("Number 2:", num2)
print("Sum =", sum)
# Out:
# Number 1: 10
# Number 2: 20
# Sum = 30

# %%
number = 17


if number % 2 == 0:
    print(number, "is Even")
else:
    print(number, "is Odd")
# Out:
# 17 is Odd

# %%
a = 15
b = 30
c = 22

largest = max(a, b, c)

print("Largest Number =", largest)
# Out:
# Largest Number = 30

# %%
# Swapping Two Numbers
x = 10
z = 20

print("Before Swapping")
print("x =", x)
print("z =", z)

x, z = z, x

print("After Swapping")
print("x =", x)
print("z =", z)
# Out:
# Before Swapping
# x = 10
# z = 20
# After Swapping
# x = 20
# z = 10

# %%
# Factorial of a Number
n = int(input("Enter a number to calculate its factorial: "))
factorial = 1

for i in range(1, n + 1):
    factorial *= i

print("Factorial of", n, "=", factorial)
# Out:
# Factorial of 5 = 120

# %%
number = 29

is_prime = True

if number <= 1:
    is_prime = False
else:
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            is_prime = False
            break

if is_prime:
    print(number, "is a Prime Number")
else:
    print(number, "is Not a Prime Number")
# Out:
# 29 is a Prime Number

# %%
text = "Machine Learning"

reverse = text[::-1]

print("Original String:", text)
print("Reversed String:", reverse)
# Out:
# Original String: Machine Learning
# Reversed String: gninraeL enihcaM
